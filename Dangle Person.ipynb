# %%
## Having issues removing all instances of a letter from underscores. Tried the enumerate method 
## Need to add a q method at anytime

import random
from IPython.display import clear_output as co

class Words:
    
    def __init__(self):
        self.list = ['orange', 'line', 'pear', 'tomato', 'peach', 
                 'melon', 'cantaloupe', 'grape', 'blueberry', 'raspberry']
        self.random = random.choice(self.list)
        self.spaces= len(self.random)*"_"
        self.splits= [char for char in self.random]
        
#     def

class Game:
    
    guessed=[]
   
    word=Words()
    tries=7

    game_over=False
    while not game_over:
        if tries==0:
            co()
            print(f'Game Over: Word was {word.random}')
        if word.random == word.spaces:
            co()
            done=True
            print("The word was: " + word.random)
            print("You won!")
            break

        print("Welcome to Dangle Person Thing")

        confirm = input("Press 'Enter' to continue. Type 'quit' to exit program. ").lower()
        co()
        if confirm == 'quit':
            game_over = True

        else:
            done = False
            co()
            while not done and tries >0:
                co()
                print("Your word is " + str(len(word.random))+ " characters long.")
                print("\n"+word.spaces)
                print("\n\nTries left: "+ tries*"X")
                print("Letters guessed: " + str(guessed))
                guess = input("\nWould you like to guess a letter? ")
                
                if len(guess)==1:

                    if guess in guessed:
                        input ("You already guessed this letter!" )
                        co()
                        
                    elif guess in word.random:
                    #need to make both into lists, enumerate, replace, save
#                             for idx, letter in enumerate(self,text):
#                                 if guess==letter:
#                                     spaces[idx]=letter
                        guessed.append(guess)
                        char=word.splits.index(guess)
                        word.spaces = (word.spaces[:char] + guess + word.spaces[char + 1:])
                        print("\nGuessed letters: "+ str(guessed))
                        print("\nTries left: "+ tries*"X")
                    else:
                        guessed.append.guess
                        tries = tries -1
                        print(f'{guess} is not a letter in the word. Guess again but you only have {tries} tries left.')
                        print("\nGuessed letters: "+ str(guessed))
                        print("\nTries left: "+ tries*"X")
# Out:
# Your word is 10 characters long.
#
# _a___l__p_
#
#
# Tries left: XXXXXXX
# Letters guessed: ['a', 'p', 'l']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-494bd18100ce> in <module>
#      19 #     def
#      20
# ---> 21 class Game:
#      22
#      23     guessed=[]
#
# <ipython-input-20-494bd18100ce> in Game()
#      54                 print("\n\nTries left: "+ tries*"X")
#      55                 print("Letters guessed: " + str(guessed))
# ---> 56                 guess = input("\nWould you like to guess a letter? ")
#      57
#      58                 if len(guess)==1:
#
# ~/opt/anaconda3/envs/march/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# ...
